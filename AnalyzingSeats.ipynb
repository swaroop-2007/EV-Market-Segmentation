# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Data/Car details v3.csv')
data.describe(include='all')
# Out:
#                           name         year  ...          torque        seats
# count                     8128  8128.000000  ...            7906  7907.000000
# unique                    2058          NaN  ...             441          NaN
# top     Maruti Swift Dzire VDI          NaN  ...  190Nm@ 2000rpm          NaN
# freq                       129          NaN  ...             530          NaN
# mean                       NaN  2013.804011  ...             NaN     5.416719
# std                        NaN     4.044249  ...             NaN     0.959588
# min                        NaN  1983.000000  ...             NaN     2.000000
# 25%                        NaN  2011.000000  ...             NaN     5.000000
# 50%                        NaN  2015.000000  ...             NaN     5.000000
# 75%                        NaN  2017.000000  ...             NaN     5.000000
# max                        NaN  2020.000000  ...             NaN    14.000000
#
# [11 rows x 13 columns]

# %%
data['seats'].unique()
# Out:
# array([ 5.,  4., nan,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %%
data = data.dropna()

# %%
data['seats'].unique()
# Out:
# array([ 5.,  4.,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %%
data_map = data.copy()
#data_map['seats'] = data_map['seats'].map({5:0, 4:1, 7:2, 8:3, 6:4, 9:5, 10:6, 14:7, 2:8})
data_map
# Out:
#                               name  year  ...                     torque  seats
# 0           Maruti Swift Dzire VDI  2014  ...             190Nm@ 2000rpm    5.0
# 1     Skoda Rapid 1.5 TDI Ambition  2014  ...        250Nm@ 1500-2500rpm    5.0
# 2         Honda City 2017-2020 EXi  2006  ...      12.7@ 2,700(kgm@ rpm)    5.0
# 3        Hyundai i20 Sportz Diesel  2010  ...   22.4 kgm at 1750-2750rpm    5.0
# 4           Maruti Swift VXI BSIII  2007  ...      11.5@ 4,500(kgm@ rpm)    5.0
# ...                            ...   ...  ...                        ...    ...
# 8123             Hyundai i20 Magna  2013  ...           113.7Nm@ 4000rpm    5.0
# 8124         Hyundai Verna CRDi SX  2007  ...  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125        Maruti Swift Dzire ZDi  2009  ...             190Nm@ 2000rpm    5.0
# 8126               Tata Indigo CR4  2013  ...        140Nm@ 1800-3000rpm    5.0
# 8127               Tata Indigo CR4  2013  ...        140Nm@ 1800-3000rpm    5.0
#
# ...

# %%
x = data_map.iloc[:,12:13]
x
# Out:
#       seats
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
# ...     ...
# 8123    5.0
# 8124    5.0
# 8125    5.0
# 8126    5.0
# 8127    5.0
#
# [7906 rows x 1 columns]

# %%
kmeans = KMeans(9)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=9, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
idclus = kmeans.fit_predict(x)
idclus
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int32)

# %%
data_clus = data_map.copy()
data_clus['Clusters'] = idclus
data_clus
# Out:
#                               name  year  ...  seats  Clusters
# 0           Maruti Swift Dzire VDI  2014  ...    5.0         2
# 1     Skoda Rapid 1.5 TDI Ambition  2014  ...    5.0         2
# 2         Honda City 2017-2020 EXi  2006  ...    5.0         2
# 3        Hyundai i20 Sportz Diesel  2010  ...    5.0         2
# 4           Maruti Swift VXI BSIII  2007  ...    5.0         2
# ...                            ...   ...  ...    ...       ...
# 8123             Hyundai i20 Magna  2013  ...    5.0         2
# 8124         Hyundai Verna CRDi SX  2007  ...    5.0         2
# 8125        Maruti Swift Dzire ZDi  2009  ...    5.0         2
# 8126               Tata Indigo CR4  2013  ...    5.0         2
# 8127               Tata Indigo CR4  2013  ...    5.0         2
#
# [7906 rows x 14 columns]

# %%
plt.scatter(data_clus['year'],data_clus['seats'],c=data_clus['Clusters'],cmap='rainbow')
#plt.xlim(-180,180)
#plt.ylim(-90,90)
plt.grid(False)
plt.show()
