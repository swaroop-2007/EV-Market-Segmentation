# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("EV Stats-1.csv")
df=df.drop('Sl. No',axis=1)
df.head()
# Out:
#             State  \
# 0  Andhra Pradesh
# 1           Assam
# 2           Bihar
# 3    Chhattisgarh
# 4           Delhi
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                                431
# 1                                                463
# 2                                                252
# 3                                                613
# 4                                               1395
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                692
# 1                                138
# 2                                430
# 3                                382
# 4                                251
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                              4689
# 1                                              1006
# 2                                              2148
# 3                                              2078
# ...

# %% [markdown]
# GRAPH FOR TOP 10 States Which Has Highest Total Number of EV

# %%
newdf=df.sort_values('Total in state',ascending=False)
newdf.reset_index()
newdf=newdf.reset_index(drop=True)
newdf.head()
# Out:
#            State  \
# 0    Maharashtra
# 1        Gujarat
# 2  Uttar Pradesh
# 3        Haryana
# 4          Delhi
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               2630
# 1                                               7182
# 2                                               2954
# 3                                               3162
# 4                                               1395
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                               2097
# 1                                217
# 2                               2355
# 3                               1504
# 4                                251
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                             10146
# 1                                              8476
# 2                                             15199
# 3                                             13908
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Total in state",data=newdf.iloc[:10]).set(title='TOP 10 States Which has Highest Total No. of E.V')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Total No. of E.V')]

# %%
newdf1=df.sort_values('Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)',ascending=False)
newdf1.reset_index()
newdf1=newdf1.reset_index(drop=True)
newdf1.head()
# Out:
#            State  \
# 0        Gujarat
# 1        Haryana
# 2  Uttar Pradesh
# 3    Maharashtra
# 4      Rajasthan
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               7182
# 1                                               3162
# 2                                               2954
# 3                                               2630
# 4                                               2036
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                217
# 1                               1504
# 2                               2355
# 3                               2097
# 4                               1153
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                              8476
# 1                                             13908
# 2                                             15199
# 3                                             10146
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y='Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)',data=newdf1.iloc[:10]).set(title='TOP 10 States Which has Highest Two Wheelers(L1 & L2 as per CMVR)')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Two Wheelers(L1 & L2 as per CMVR)')]

# %%
newdf2=df.sort_values('Two Wheelers (Category L2 (CMVR))',ascending=False)
newdf2.reset_index()
newdf2=newdf2.reset_index(drop=True)
newdf2.head()
# Out:
#            State  \
# 0  Uttar Pradesh
# 1    Maharashtra
# 2        Haryana
# 3      Rajasthan
# 4      Karnataka
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               2954
# 1                                               2630
# 2                                               3162
# 3                                               2036
# 4                                                784
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                               2355
# 1                               2097
# 2                               1504
# 3                               1153
# 4                               1104
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                             15199
# 1                                             10146
# 2                                             13908
# 3                                              8375
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Two Wheelers (Category L2 (CMVR))",data=newdf2.iloc[:10]).set(title='TOP 10 States Which has Highest Two Wheelers(L2 as per CMVR)')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Two Wheelers(L2 as per CMVR)')]

# %%
newdf3=df.sort_values('Two Wheelers (Max power not exceeding 250 Watts)',ascending=False)
newdf3.reset_index()
newdf3=newdf3.reset_index(drop=True)
newdf3.head()
# Out:
#            State  \
# 0  Uttar Pradesh
# 1        Haryana
# 2    West Bengal
# 3    Maharashtra
# 4        Gujarat
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               2954
# 1                                               3162
# 2                                               1451
# 3                                               2630
# 4                                               7182
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                               2355
# 1                               1504
# 2                                 65
# 3                               2097
# 4                                217
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                             15199
# 1                                             13908
# 2                                             10781
# 3                                             10146
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Two Wheelers (Max power not exceeding 250 Watts)",data=newdf3.iloc[:10]).set(title='TOP 10 States Which has Highest Two Wheelers(Max power not exceeding 250 Watts')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Two Wheelers(Max power not exceeding 250 Watts')]

# %%
newdf4=df.sort_values('Three Wheelers (Category L5 slow speed as per CMVR)',ascending=False)
newdf4.reset_index()
newdf4=newdf4.reset_index(drop=True)
newdf4.head()
# Out:
#            State  \
# 0  Uttar Pradesh
# 1        Haryana
# 2   Chhattisgarh
# 3     Uttarkhand
# 4      Rajasthan
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               2954
# 1                                               3162
# 2                                                613
# 3                                                423
# 4                                               2036
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                               2355
# 1                               1504
# 2                                382
# 3                                168
# 4                               1153
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                             15199
# 1                                             13908
# 2                                              2078
# 3                                              3239
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Three Wheelers (Category L5 slow speed as per CMVR)",data=newdf4.iloc[:10]).set(title='TOP 10 States Which has Highest Three Wheelers(Category L5 slow speed as per CMVR)')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Three Wheelers(Category L5 slow speed as per CMVR)')]

# %%
newdf5=df.sort_values('Three Wheelers (Category L5 as per CMVR)',ascending=False)
newdf5.reset_index()
newdf5=newdf5.reset_index(drop=True)
newdf5.head()
# Out:
#             State  \
# 0   Uttar Pradesh
# 1           Assam
# 2    Chhattisgarh
# 3  Madhya Pradesh
# 4       Rajasthan
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               2954
# 1                                                463
# 2                                                613
# 3                                                503
# 4                                               2036
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                               2355
# 1                                138
# 2                                382
# 3                                378
# 4                               1153
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                             15199
# 1                                              1006
# 2                                              2078
# 3                                              2904
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Three Wheelers (Category L5 as per CMVR)",data=newdf5.iloc[:10]).set(title='TOP 10 States Which has Highest Three Wheelers (Category L5 as per CMVR)')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Three Wheelers (Category L5 as per CMVR)')]

# %%
newdf6=df.sort_values('Passenger Cars (Category M1 as per CMVR)',ascending=False)
newdf6.reset_index()
newdf6=newdf6.reset_index(drop=True)
newdf6.head()
# Out:
#          State  \
# 0  Maharashtra
# 1      Gujarat
# 2        Delhi
# 3    Karnataka
# 4   Tamil Nadu
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               2630
# 1                                               7182
# 2                                               1395
# 3                                                784
# 4                                                491
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                               2097
# 1                                217
# 2                                251
# 3                               1104
# 4                                863
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                             10146
# 1                                              8476
# 2                                              5018
# 3                                              3252
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Passenger Cars (Category M1 as per CMVR)",data=newdf6.iloc[:10]).set(title='TOP 10 States Which has Highest Passenger Cars (Category M1 as per CMVR)')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Passenger Cars (Category M1 as per CMVR)')]

# %%
newdf7=df.sort_values('Buses',ascending=False)
newdf7.reset_index()
newdf7=newdf7.reset_index(drop=True)
newdf7.head()
# Out:
#          State  \
# 0        Delhi
# 1  Maharashtra
# 2    Karnataka
# 3          Goa
# 4       Kerala
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)  \
# 0                                               1395
# 1                                               2630
# 2                                                784
# 3                                                  0
# 4                                                432
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                251
# 1                               2097
# 2                               1104
# 3                                  0
# 4                                 78
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                              5018
# 1                                             10146
# 2                                              3252
# 3                                                 0
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='State',y="Buses",data=newdf7.iloc[:10]).set(title='TOP 10 States Which has Highest Buses')
# Out:
# [Text(0.5, 1.0, 'TOP 10 States Which has Highest Buses')]
